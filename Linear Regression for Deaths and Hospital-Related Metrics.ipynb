# %%
# Import libraries
# %matplotlib inline

import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# increase the size and quality of any plots we produce
import matplotlib as mpl
mpl.rcParams["figure.dpi"] = 150

from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## 0 - Load the DataFrame

# %%
# load dataframe
df = pd.read_csv("https://raw.githubusercontent.com/mellanyquiroz/DS4A-TeamProject/master/data/Merged_precovid_duringcovid_deaths_and_hospital_metrics.csv",index_col="COUNTY")
df.head()
# Out:
#            PRECOVID_RATES  PRECOVID_COUNTS  COVID_RATES  COVID_COUNTS  \
# COUNTY
# Alameda             3.502             63.0         8.09         144.0
# Alpine              0.000              0.0         0.00           0.0
# Amador              6.556              3.0        13.07           4.0
# Butte               6.900             16.2        11.54          26.0
# Calaveras          10.566              4.6         7.00           2.0
#
#            TOTAL_FAC  TOTAL_NUMBER_BEDS  COUNT_NOER_FAC  COUNT_ER_FAC  \
# COUNTY
# Alameda        340.0             9074.0           327.0          13.0
# Alpine           0.0                0.0             0.0           0.0
# Amador           5.0              251.0             4.0           1.0
# Butte           44.0             1387.0            41.0           3.0
# Calaveras        5.0              124.0             4.0           1.0
#
#            ER_BEDS  TOTALFAC_PER_POP  TOTALBEDS_PER_POP  ERFAC_PER_POP  \
# COUNTY
# Alameda     2894.0         20.232315         539.964772       0.773588
# Alpine         0.0          0.000000           0.000000       0.000000
# Amador        52.0         12.362162         620.580527       2.472432
# Butte        467.0         22.348639         704.490045       1.523771
# Calaveras     25.0         10.794706         267.708716       2.158941
#
#            ERBEDS_PER_POP  ERFAC_PER_AREA
# COUNTY
# Alameda        172.212701        0.017589
# Alpine           0.000000        0.000000
# Amador         128.566484        0.001682
# Butte          237.200325        0.001833
# Calaveras       53.973531        0.000980

# %%
# remove No ER facility number
df = df.drop(columns="COUNT_NOER_FAC")

# %%
# statistics of each column
df.describe()
# Out:
#        PRECOVID_RATES  PRECOVID_COUNTS  COVID_RATES  COVID_COUNTS  \
# count       58.000000        58.000000    58.000000     58.000000
# mean         7.047000        40.744828    12.027586     92.913793
# std          4.394006        78.606841     8.527419    203.349521
# min          0.000000         0.000000     0.000000      0.000000
# 25%          4.258500         3.850000     6.450000      4.000000
# 50%          6.222000        13.000000    10.870000     24.500000
# 75%          8.615500        39.500000    15.900000     79.250000
# max         22.304000       457.400000    44.510000   1300.000000
#
#          TOTAL_FAC  TOTAL_NUMBER_BEDS  COUNT_ER_FAC       ER_BEDS  \
# count    58.000000          58.000000     58.000000     58.000000
# mean    143.931034        3610.224138      5.741379   1266.293103
# std     499.977644        9036.753772     10.289767   2981.164055
# min       0.000000           0.000000      0.000000      0.000000
# 25%       8.250000         172.000000      1.000000     64.500000
# 50%      27.500000         941.500000      2.500000    298.000000
# 75%      95.500000        3333.500000      6.750000   1194.750000
# max    3781.000000       65542.000000     72.000000  20947.000000
#
#        TOTALFAC_PER_POP  TOTALBEDS_PER_POP  ERFAC_PER_POP  ERBEDS_PER_POP  \
# count         58.000000          58.000000      58.000000       58.000000
# mean          18.498336         522.331033       2.490566      189.234635
# std            9.637196         285.484200       3.827761      156.289132
# min            0.000000           0.000000       0.000000        0.000000
# 25%           12.447112         378.115384       0.744955      129.355708
# 50%           16.176262         487.177013       1.124202      169.626388
# 75%           22.609171         614.122250       2.394060      201.725443
# max           66.203244        1856.192962      22.413986     1176.734282
#
#        ERFAC_PER_AREA
# count       58.000000
# mean         0.006969
# std          0.028131
# min          0.000000
# 25%          0.000720
# 50%          0.001193
# 75%          0.003692
# max          0.213246

# %% [markdown]
# ## 1- Exploratory Correlations

# %%
# divide the dataframe into Count variables and Rate/density variables
count_df = df[["PRECOVID_COUNTS","COVID_COUNTS","TOTAL_FAC","TOTAL_NUMBER_BEDS","COUNT_ER_FAC","ER_BEDS"]]
rate_df = df[["PRECOVID_RATES","COVID_RATES","TOTALFAC_PER_POP","TOTALBEDS_PER_POP","ERFAC_PER_POP","ERBEDS_PER_POP","ERFAC_PER_AREA"]]

# %%
# correlations of variables in count dataframe
corr = count_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_42313_row0_col0,#T_42313_row1_col1,#T_42313_row2_col2,#T_42313_row3_col3,#T_42313_row4_col4,#T_42313_row5_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_42313_row0_col1{
#             background-color:  #f08b6e;
#             color:  #000000;
#         }#T_42313_row0_col2,#T_42313_row0_col3,#T_42313_row0_col4,#T_42313_row0_col5,#T_42313_row2_col0,#T_42313_row2_col1{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_42313_row1_col0{
#             background-color:  #e16751;
#             color:  #000000;
#         }#T_42313_row1_col2{
#             background-color:  #b5cdfa;
#             color:  #000000;
#         }#T_42313_row1_col3{
#             background-color:  #bed2f6;
#             color:  #000000;
#         }#T_42313_row1_col4{
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }#T_42313_row1_col5{
#             background-color:  #c9d7f0;
#             color:  #000000;
#         }#T_42313_row2_col3{
#             background-color:  #ee8669;
#             color:  #000000;
#         }#T_42313_row2_col4{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_42313_row2_col5{
#             background-color:  #c5d6f2;
#             color:  #000000;
#         }#T_42313_row3_col0{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_42313_row3_col1{
#             background-color:  #d3dbe7;
#             color:  #000000;
#         }#T_42313_row3_col2{
#             background-color:  #da5a49;
#             color:  #000000;
#         }#T_42313_row3_col4{
#             background-color:  #f7a889;
#             color:  #000000;
#         }#T_42313_row3_col5{
#             background-color:  #d1493f;
#             color:  #f1f1f1;
#         }#T_42313_row4_col0{
#             background-color:  #f4c6af;
#             color:  #000000;
#         }#T_42313_row4_col1{
#             background-color:  #f7b396;
#             color:  #000000;
#         }#T_42313_row4_col2{
#             background-color:  #f7a688;
#             color:  #000000;
#         }#T_42313_row4_col3{
#             background-color:  #ed8366;
#             color:  #000000;
#         }#T_42313_row4_col5,#T_42313_row5_col4{
#             background-color:  #e97a5f;
#             color:  #000000;
#         }#T_42313_row5_col0{
#             background-color:  #f4c5ad;
#             color:  #000000;
#         }#T_42313_row5_col1{
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }#T_42313_row5_col2{
#             background-color:  #f18d6f;
#             color:  #000000;
#         }#T_42313_row5_col3{
#             background-color:  #c83836;
#             color:  #f1f1f1;
#         }</style><table id="T_42313_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PRECOVID_COUNTS</th>        <th class="col_heading level0 col1" >COVID_COUNTS</th>        <th class="col_heading level0 col2" >TOTAL_FAC</th>        <th class="col_heading level0 col3" >TOTAL_NUMBER_BEDS</th>        <th class="col_heading level0 col4" >COUNT_ER_FAC</th>        <th class="col_heading level0 col5" >ER_BEDS</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_42313_level0_row0" class="row_heading level0 row0" >PRECOVID_COUNTS</th>
#                         <td id="T_42313_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_42313_row0_col1" class="data row0 col1" >0.976495</td>
#                         <td id="T_42313_row0_col2" class="data row0 col2" >0.828411</td>
#                         <td id="T_42313_row0_col3" class="data row0 col3" >0.904219</td>
#                         <td id="T_42313_row0_col4" class="data row0 col4" >0.934530</td>
#                         <td id="T_42313_row0_col5" class="data row0 col5" >0.935051</td>
#             </tr>
#             <tr>
#                         <th id="T_42313_level0_row1" class="row_heading level0 row1" >COVID_COUNTS</th>
#                         <td id="T_42313_row1_col0" class="data row1 col0" >0.976495</td>
#                         <td id="T_42313_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_42313_row1_col2" class="data row1 col2" >0.891401</td>
#                         <td id="T_42313_row1_col3" class="data row1 col3" >0.941673</td>
#                         <td id="T_42313_row1_col4" class="data row1 col4" >0.965421</td>
#                         <td id="T_42313_row1_col5" class="data row1 col5" >0.962937</td>
#             </tr>
#             <tr>
#                         <th id="T_42313_level0_row2" class="row_heading level0 row2" >TOTAL_FAC</th>
#                         <td id="T_42313_row2_col0" class="data row2 col0" >0.828411</td>
#                         <td id="T_42313_row2_col1" class="data row2 col1" >0.891401</td>
#                         <td id="T_42313_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_42313_row2_col3" class="data row2 col3" >0.980377</td>
#                         <td id="T_42313_row2_col4" class="data row2 col4" >0.951415</td>
#                         <td id="T_42313_row2_col5" class="data row2 col5" >0.962089</td>
#             </tr>
#             <tr>
#                         <th id="T_42313_level0_row3" class="row_heading level0 row3" >TOTAL_NUMBER_BEDS</th>
#                         <td id="T_42313_row3_col0" class="data row3 col0" >0.904219</td>
#                         <td id="T_42313_row3_col1" class="data row3 col1" >0.941673</td>
#                         <td id="T_42313_row3_col2" class="data row3 col2" >0.980377</td>
#                         <td id="T_42313_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_42313_row3_col4" class="data row3 col4" >0.981161</td>
#                         <td id="T_42313_row3_col5" class="data row3 col5" >0.994586</td>
#             </tr>
#             <tr>
#                         <th id="T_42313_level0_row4" class="row_heading level0 row4" >COUNT_ER_FAC</th>
#                         <td id="T_42313_row4_col0" class="data row4 col0" >0.934530</td>
#                         <td id="T_42313_row4_col1" class="data row4 col1" >0.965421</td>
#                         <td id="T_42313_row4_col2" class="data row4 col2" >0.951415</td>
#                         <td id="T_42313_row4_col3" class="data row4 col3" >0.981161</td>
#                         <td id="T_42313_row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_42313_row4_col5" class="data row4 col5" >0.988460</td>
#             </tr>
#             <tr>
#                         <th id="T_42313_level0_row5" class="row_heading level0 row5" >ER_BEDS</th>
#                         <td id="T_42313_row5_col0" class="data row5 col0" >0.935051</td>
#                         <td id="T_42313_row5_col1" class="data row5 col1" >0.962937</td>
#                         <td id="T_42313_row5_col2" class="data row5 col2" >0.962089</td>
#                         <td id="T_42313_row5_col3" class="data row5 col3" >0.994586</td>
#                         <td id="T_42313_row5_col4" class="data row5 col4" >0.988460</td>
#                         <td id="T_42313_row5_col5" class="data row5 col5" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
# correlations of variables in rate dataframe
corr = rate_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_2fd0b_row0_col0,#T_2fd0b_row1_col1,#T_2fd0b_row2_col2,#T_2fd0b_row3_col3,#T_2fd0b_row4_col4,#T_2fd0b_row5_col5,#T_2fd0b_row6_col6{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_2fd0b_row0_col1{
#             background-color:  #f3c7b1;
#             color:  #000000;
#         }#T_2fd0b_row0_col2{
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }#T_2fd0b_row0_col3,#T_2fd0b_row1_col4,#T_2fd0b_row1_col5,#T_2fd0b_row2_col6,#T_2fd0b_row3_col0,#T_2fd0b_row4_col1,#T_2fd0b_row6_col2{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_2fd0b_row0_col4{
#             background-color:  #adc9fd;
#             color:  #000000;
#         }#T_2fd0b_row0_col5{
#             background-color:  #7295f4;
#             color:  #000000;
#         }#T_2fd0b_row0_col6{
#             background-color:  #92b4fe;
#             color:  #000000;
#         }#T_2fd0b_row1_col0{
#             background-color:  #edd2c3;
#             color:  #000000;
#         }#T_2fd0b_row1_col2,#T_2fd0b_row3_col6{
#             background-color:  #6180e9;
#             color:  #000000;
#         }#T_2fd0b_row1_col3{
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }#T_2fd0b_row1_col6{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_2fd0b_row2_col0{
#             background-color:  #799cf8;
#             color:  #000000;
#         }#T_2fd0b_row2_col1{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }#T_2fd0b_row2_col3{
#             background-color:  #dbdcde;
#             color:  #000000;
#         }#T_2fd0b_row2_col4,#T_2fd0b_row3_col4{
#             background-color:  #9abbff;
#             color:  #000000;
#         }#T_2fd0b_row2_col5{
#             background-color:  #6788ee;
#             color:  #000000;
#         }#T_2fd0b_row3_col1{
#             background-color:  #6a8bef;
#             color:  #000000;
#         }#T_2fd0b_row3_col2{
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }#T_2fd0b_row3_col5{
#             background-color:  #cad8ef;
#             color:  #000000;
#         }#T_2fd0b_row4_col0,#T_2fd0b_row4_col2{
#             background-color:  #90b2fe;
#             color:  #000000;
#         }#T_2fd0b_row4_col3{
#             background-color:  #7b9ff9;
#             color:  #000000;
#         }#T_2fd0b_row4_col5{
#             background-color:  #ec8165;
#             color:  #000000;
#         }#T_2fd0b_row4_col6{
#             background-color:  #3f53c6;
#             color:  #f1f1f1;
#         }#T_2fd0b_row5_col0{
#             background-color:  #6282ea;
#             color:  #000000;
#         }#T_2fd0b_row5_col1{
#             background-color:  #4c66d6;
#             color:  #000000;
#         }#T_2fd0b_row5_col2{
#             background-color:  #6e90f2;
#             color:  #000000;
#         }#T_2fd0b_row5_col3{
#             background-color:  #c1d4f4;
#             color:  #000000;
#         }#T_2fd0b_row5_col4{
#             background-color:  #ea7b60;
#             color:  #000000;
#         }#T_2fd0b_row5_col6{
#             background-color:  #7699f6;
#             color:  #000000;
#         }#T_2fd0b_row6_col0{
#             background-color:  #7da0f9;
#             color:  #000000;
#         }#T_2fd0b_row6_col1{
#             background-color:  #edd1c2;
#             color:  #000000;
#         }#T_2fd0b_row6_col3,#T_2fd0b_row6_col4{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_2fd0b_row6_col5{
#             background-color:  #6f92f3;
#             color:  #000000;
#         }</style><table id="T_2fd0b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >PRECOVID_RATES</th>        <th class="col_heading level0 col1" >COVID_RATES</th>        <th class="col_heading level0 col2" >TOTALFAC_PER_POP</th>        <th class="col_heading level0 col3" >TOTALBEDS_PER_POP</th>        <th class="col_heading level0 col4" >ERFAC_PER_POP</th>        <th class="col_heading level0 col5" >ERBEDS_PER_POP</th>        <th class="col_heading level0 col6" >ERFAC_PER_AREA</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_2fd0b_level0_row0" class="row_heading level0 row0" >PRECOVID_RATES</th>
#                         <td id="T_2fd0b_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_2fd0b_row0_col1" class="data row0 col1" >0.559893</td>
#                         <td id="T_2fd0b_row0_col2" class="data row0 col2" >0.175639</td>
#                         <td id="T_2fd0b_row0_col3" class="data row0 col3" >-0.022900</td>
#                         <td id="T_2fd0b_row0_col4" class="data row0 col4" >0.243367</td>
#                         <td id="T_2fd0b_row0_col5" class="data row0 col5" >0.108534</td>
#                         <td id="T_2fd0b_row0_col6" class="data row0 col6" >0.185207</td>
#             </tr>
#             <tr>
#                         <th id="T_2fd0b_level0_row1" class="row_heading level0 row1" >COVID_RATES</th>
#                         <td id="T_2fd0b_row1_col0" class="data row1 col0" >0.559893</td>
#                         <td id="T_2fd0b_row1_col1" class="data row1 col1" >1.000000</td>
#                         <td id="T_2fd0b_row1_col2" class="data row1 col2" >0.030979</td>
#                         <td id="T_2fd0b_row1_col3" class="data row1 col3" >0.025531</td>
#                         <td id="T_2fd0b_row1_col4" class="data row1 col4" >-0.146572</td>
#                         <td id="T_2fd0b_row1_col5" class="data row1 col5" >-0.078648</td>
#                         <td id="T_2fd0b_row1_col6" class="data row1 col6" >0.507841</td>
#             </tr>
#             <tr>
#                         <th id="T_2fd0b_level0_row2" class="row_heading level0 row2" >TOTALFAC_PER_POP</th>
#                         <td id="T_2fd0b_row2_col0" class="data row2 col0" >0.175639</td>
#                         <td id="T_2fd0b_row2_col1" class="data row2 col1" >0.030979</td>
#                         <td id="T_2fd0b_row2_col2" class="data row2 col2" >1.000000</td>
#                         <td id="T_2fd0b_row2_col3" class="data row2 col3" >0.483859</td>
#                         <td id="T_2fd0b_row2_col4" class="data row2 col4" >0.181574</td>
#                         <td id="T_2fd0b_row2_col5" class="data row2 col5" >0.074273</td>
#                         <td id="T_2fd0b_row2_col6" class="data row2 col6" >-0.105590</td>
#             </tr>
#             <tr>
#                         <th id="T_2fd0b_level0_row3" class="row_heading level0 row3" >TOTALBEDS_PER_POP</th>
#                         <td id="T_2fd0b_row3_col0" class="data row3 col0" >-0.022900</td>
#                         <td id="T_2fd0b_row3_col1" class="data row3 col1" >0.025531</td>
#                         <td id="T_2fd0b_row3_col2" class="data row3 col2" >0.483859</td>
#                         <td id="T_2fd0b_row3_col3" class="data row3 col3" >1.000000</td>
#                         <td id="T_2fd0b_row3_col4" class="data row3 col4" >0.182702</td>
#                         <td id="T_2fd0b_row3_col5" class="data row3 col5" >0.388887</td>
#                         <td id="T_2fd0b_row3_col6" class="data row3 col6" >0.031583</td>
#             </tr>
#             <tr>
#                         <th id="T_2fd0b_level0_row4" class="row_heading level0 row4" >ERFAC_PER_POP</th>
#                         <td id="T_2fd0b_row4_col0" class="data row4 col0" >0.243367</td>
#                         <td id="T_2fd0b_row4_col1" class="data row4 col1" >-0.146572</td>
#                         <td id="T_2fd0b_row4_col2" class="data row4 col2" >0.181574</td>
#                         <td id="T_2fd0b_row4_col3" class="data row4 col3" >0.182702</td>
#                         <td id="T_2fd0b_row4_col4" class="data row4 col4" >1.000000</td>
#                         <td id="T_2fd0b_row4_col5" class="data row4 col5" >0.793522</td>
#                         <td id="T_2fd0b_row4_col6" class="data row4 col6" >-0.088054</td>
#             </tr>
#             <tr>
#                         <th i

# %%
# function to plot a matrix of scatterplot
def plotting(df):
    g = sns.PairGrid(df)
    g.map(sns.scatterplot)

# %% [markdown]
# ## 3 - Linear Regression on Death Rates

# %%
# Build a function to run a linear regression and plot it using variables in a dataset
def linear_regression(dataframe,variable_x,variable_y):
    ''' This function takes a dataframe and its variables,
    plot a scatter chart, then fit the data in a linear regression model
    Input: dataframe, x variable, y variable
    Output: a scatter plot, regression score, a scatter of predicted value '''

    # plot the data on a scatter chart
    sns.lmplot(x=variable_x,y=variable_y,data=dataframe,order=2,ci=None)

    # run linear regression
    X = np.array(dataframe[variable_x]).reshape(-1,1)
    y = np.array(dataframe[variable_y]).reshape(-1,1)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)
    
    regr = LinearRegression()
    regr.fit(X_train, y_train)
    score = regr.score(X_test, y_test)
    print("Regression score is %f." % score)

    # plot the predicted data
    y_pred = regr.predict(X_test)
    plt.scatter(X_test, y_test, color ='r')
    plt.plot(X_test, y_pred, color ='b')
    plt.show()

# %%
rate_df1 = df[["PRECOVID_RATES","TOTALFAC_PER_POP"]]
corr1 = rate_df1.corr()
corr1
# Out:
#                   PRECOVID_RATES  TOTALFAC_PER_POP
# PRECOVID_RATES          1.000000          0.175639
# TOTALFAC_PER_POP        0.175639          1.000000

# %%
import statsmodels.api as sm

X = rate_df["TOTALFAC_PER_POP"]
y = rate_df["PRECOVID_RATES"] 

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()

#63% OF variance in hospital facility per pop can be explained by pre covid death rates
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:         PRECOVID_RATES   R-squared (uncentered):                   0.637
# Model:                            OLS   Adj. R-squared (uncentered):              0.631
# Method:                 Least Squares   F-statistic:                              100.0
# Date:                Thu, 27 Jan 2022   Prob (F-statistic):                    3.73e-14
# Time:                        18:30:14   Log-Likelihood:                         -175.54
# No. Observations:                  58   AIC:                                      353.1
# Df Residuals:                      57   BIC:                                      355.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# TOTALFAC_PER_POP     0.3176      0.032     10.002      0.000       0.254       0.381
# ==============================================================================
# Omnibus:                       27.457   Durbin-Watson:                   1.961
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              116.664
# Skew:                          -1.071   Prob(JB):                     4.64e-26
# Kurtosis:                       9.610   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
linear_regression(rate_df,"PRECOVID_RATES","TOTALFAC_PER_POP")
# Out:
# Regression score is -0.079510.

# %%
linear_regression(rate_df,"COVID_RATES","TOTALFAC_PER_POP")

# %%
linear_regression(rate_df,"PRECOVID_RATES","TOTALBEDS_PER_POP")

# %%
linear_regression(rate_df,"COVID_RATES","TOTALBEDS_PER_POP")

# %%
linear_regression(rate_df,"PRECOVID_RATES","ERFAC_PER_POP")

# %%
linear_regression(rate_df,"COVID_RATES","ERFAC_PER_POP")

# %%
linear_regression(rate_df,"PRECOVID_RATES","ERFAC_PER_AREA")

# %%
linear_regression(rate_df,"COVID_RATES","ERFAC_PER_AREA")
